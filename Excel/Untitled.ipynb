# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

excel = pd.read_excel("Excel_Basics.xlsx")
excel.head()
# Out:
#      Fruits  Quantity  Unit Price   Date Sold Total Sales Discount Value  \
# 0    Apples      10.0        15.0  2024-06-01         150             27
# 1   Bananas      15.0        10.0  2024-06-02         150             27
# 2  Cherries       7.0        12.0  2024-06-03          84          15.12
# 3     Dates      20.0        18.0  2024-06-04         360           64.8
# 4   Oranges       5.0        14.0  2024-06-05          70           12.6
#
#   Net Sales  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0       123         NaN         NaN       123.0
# 1       123         NaN         NaN         NaN
# 2     68.88         NaN         NaN         NaN
# 3     295.2         NaN         NaN         0.0
# 4      57.4         NaN         NaN         NaN
